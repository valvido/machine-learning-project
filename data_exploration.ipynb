# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/X_train.csv")
data.head()
# Out:
#           t       x_1       y_1     v_x_1     v_y_1       x_2       y_2  \
# 0  0.000000  1.000000  0.000000  0.000000  0.000000 -0.266467  0.859196
# 1  0.039062  0.999548  0.000092 -0.023159  0.004731 -0.266261  0.858781
# 2  0.078125  0.998190  0.000370 -0.046362  0.009474 -0.265641  0.857535
# 3  0.117188  0.995925  0.000833 -0.069654  0.014239 -0.264606  0.855456
# 4  0.156250  0.992747  0.001483 -0.093080  0.019040 -0.263154  0.852540
#
#       v_x_2     v_y_2       x_3       y_3     v_x_3     v_y_3  Id
# 0  0.000000  0.000000 -0.733533 -0.859196  0.000000  0.000000   0
# 1  0.010574 -0.021257 -0.733287 -0.858874  0.012584  0.016526   1
# 2  0.021172 -0.042552 -0.732549 -0.857905  0.025189  0.033078   2
# 3  0.031817 -0.063924 -0.731318 -0.856289  0.037837  0.049685   3
# 4  0.042533 -0.085412 -0.729592 -0.854022  0.050548  0.066372   4

# %%
pd.set_option('display.max_rows', 500) 
data.head(300)
# Out:
#              t       x_1       y_1     v_x_1     v_y_1       x_2       y_2  \
# 0     0.000000  1.000000  0.000000  0.000000  0.000000 -0.266467  0.859196
# 1     0.039062  0.999548  0.000092 -0.023159  0.004731 -0.266261  0.858781
# 2     0.078125  0.998190  0.000370 -0.046362  0.009474 -0.265641  0.857535
# 3     0.117188  0.995925  0.000833 -0.069654  0.014239 -0.264606  0.855456
# 4     0.156250  0.992747  0.001483 -0.093080  0.019040 -0.263154  0.852540
# 5     0.195312  0.988650  0.002321 -0.116689  0.023888 -0.261282  0.848781
# 6     0.234375  0.983627  0.003350 -0.140528  0.028797 -0.258985  0.844173
# 7     0.273438  0.977668  0.004572 -0.164650  0.033779 -0.256258  0.838708
# 8     0.312500  0.970760  0.005990 -0.189111  0.038851 -0.253095  0.832374
# 9     0.351562  0.962888  0.007608 -0.213969  0.044027 -0.249488  0.825159
# 10    0.390625  0.954037  0.009431 -0.239288  0.049327 -0.245427  0.817049
# ...

# %% [markdown]
# the dataset contains many 10s trajectory. Each 257th row is a start of a new tajectory

# %%
data.describe()
# Out:
#                   t           x_1           y_1         v_x_1         v_y_1  \
# count  1.285000e+06  1.285000e+06  1.285000e+06  1.285000e+06  1.285000e+06
# mean   4.145262e+00 -2.812879e-01 -1.095159e-01 -1.841267e-01 -1.650011e-02
# std    3.209813e+00  1.695764e+00  1.167686e+00  8.775115e-01  8.064175e-01
# min    0.000000e+00 -3.082300e+01 -1.785773e+01 -7.299333e+01 -2.310928e+01
# 25%    1.054690e+00 -4.118489e-01 -3.928434e-01 -5.782370e-01 -2.266108e-01
# 50%    3.945310e+00  0.000000e+00  0.000000e+00 -6.909794e-02  0.000000e+00
# 75%    6.953120e+00  5.008268e-01  2.634242e-01  1.321657e-01  2.444148e-01
# max    1.000000e+01  1.634061e+01  2.627623e+01  2.350346e+01  3.467168e+01
#
#                 x_2           y_2         v_x_2         v_y_2           x_3  \
# count  1.285000e+06  1.285000e+06  1.285000e+06  1.285000e+06  1.285000e+06
# mean   7.171403e-03 -8.201144e-02  3.247712e-02 -8.360838e-02  2.741165e-01
# ...

# %%
print("Time range training set:", data["t"].min(), "to", data["t"].max())
# Out:
# Time range training set: 0.0 to 10.0

# %%
data["Id"].unique()
# Out:
# array([      0,       1,       2, ..., 1284997, 1284998, 1284999],
#       shape=(1285000,))

# %%
data["t"].unique()
# Out:
# array([ 0.       ,  0.0390625,  0.078125 ,  0.117188 ,  0.15625  ,
#         0.195312 ,  0.234375 ,  0.273438 ,  0.3125   ,  0.351562 ,
#         0.390625 ,  0.429688 ,  0.46875  ,  0.507812 ,  0.546875 ,
#         0.585938 ,  0.625    ,  0.664062 ,  0.703125 ,  0.742188 ,
#         0.78125  ,  0.820312 ,  0.859375 ,  0.898438 ,  0.9375   ,
#         0.976562 ,  1.01562  ,  1.05469  ,  1.09375  ,  1.13281  ,
#         1.17188  ,  1.21094  ,  1.25     ,  1.28906  ,  1.32812  ,
#         1.36719  ,  1.40625  ,  1.44531  ,  1.48438  ,  1.52344  ,
#         1.5625   ,  1.60156  ,  1.64062  ,  1.67969  ,  1.71875  ,
#         1.75781  ,  1.79688  ,  1.83594  ,  1.875    ,  1.91406  ,
#         1.95312  ,  1.99219  ,  2.03125  ,  2.07031  ,  2.10938  ,
#         2.14844  ,  2.1875   ,  2.22656  ,  2.26562  ,  2.30469  ,
#         2.34375  ,  2.38281  ,  2.42188  ,  2.46094  ,  2.5      ,
#         2.53906  ,  2.57812  ,  2.61719  ,  2.65625  ,  2.69531  ,
# ...

# %%
data.columns
# Out:
# Index(['t', 'x_1', 'y_1', 'v_x_1', 'v_y_1', 'x_2', 'y_2', 'v_x_2', 'v_y_2',
#        'x_3', 'y_3', 'v_x_3', 'v_y_3', 'Id'],
#       dtype='object')

# %% [markdown]
# ## Tracing random trajectories

# %% [markdown]
# note: Each trajectory consists of 258 lines, one per data point. Note that after a collision, all lines of that trajectory will be zero up to the 258th data point for that trajectory

# %%
idx = np.hstack((0, data [data.t == 10].index.values+1)) ## data [data.t == 10].index.values+1 gives the initial state of the new trajectory
                                                         ##idx are the indexes of the initial positions
idx.shape, df_train.t.min(), data.t.max()
# Out:
# ((4054,), np.float64(0.0), np.float64(10.0))

# %%
print(idx)
# Out:
# [      0     257     514 ... 1284486 1284743 1285000]

# %%
k = np.random.randint(idx.shape[0])
print(k)
pltidx = range(idx[k], 257+idx[k])
pltsquare = idx[k]
plt.plot(data.x_1[pltidx],data.y_1[pltidx])
plt.plot(data.x_2[pltidx],data.y_2[pltidx])
plt.plot(data.x_3[pltidx],data.y_3[pltidx])
    
plt.plot(data.x_1[pltsquare],data.y_1[pltsquare],'s')
plt.plot(data.x_2[pltsquare],data.y_2[pltsquare], 's')
plt.plot(data.x_3[pltsquare] ,data.y_3[pltsquare],'s')
# Out:
# 3576
